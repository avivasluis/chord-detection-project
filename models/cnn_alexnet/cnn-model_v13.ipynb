# %%
'''
v13 description:
    - Train for longer, batch normalization + gentle data augmentation
'''
# Out:
# '\nv13 description:\n    - Train for longer, batch normalization + gentle data augmentation\n'

# %%
import os
import json
import copy
import numpy as np
import pandas as pd
from pathlib import Path
import librosa
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

# %%
# Configuration
SAMPLE_RATE = 44100 
DURATION = 1  # Duration of clips in seconds (adjust based on your dataset)

n_fft = 2048
hop_length = 512

BATCH_SIZE = 32
LEARNING_RATE = 0.001
EPOCHS = 100
EARLY_STOPPING_PATIENCE = 20

NUM_CLASSES = 24 
INPUT_SIZE = (227, 227) # AlexNet input requirement 
REPRESENTATION = 'cqt_chromagram'

# %% [markdown]
# # Check class imbalance for training data

# %%
# Load the snippet summary
summary_path = Path("/kaggle/input/guitarset-chord-recognition/chords/snippet_summary.json")
with open(summary_path, "r") as f:
    summary = json.load(f)

# Build the DataFrame
rows = []
for chord in summary["train"].keys():
    rows.append({
        "chord": chord,
        "count": summary["train"][chord]["count"],
    })

df = pd.DataFrame(rows)
print(df)
# Out:
#    chord  count
# 0      C     91
# 1     Cm     28
# 2     C#     91
# 3    C#m     57
# 4      D     81
# 5     Dm     67
# 6     D#     86
# 7    D#m     57
# 8      E     86
# 9     Em     67
# 10     F    115
# 11    Fm    115
# 12    F#     76
# 13   F#m     38
# 14     G    100
# 15    Gm     96
# 16    G#     91
# 17   G#m     86
# 18     A     76
# 19    Am     38
# 20    A#     81
# 21   A#m     96
# 22     B     76
# 23    Bm     57

# %% [markdown]
# # Train the model

# %%
class GuitarChordDataset(Dataset):
    def __init__(self, root_dir, representation='spectrogram', transform=None, augment=False):
        """
        Args:
            root_dir (string): Directory with all the audio files organized by class.
            representation (string): Type of audio representation to use.
                - 'spectrogram': STFT-based power spectrogram (default)
                - 'cqt_chromagram': Constant-Q chromagram (12 pitch classes over time)
            transform (callable, optional): Optional transform to be applied.
            augment (bool): Whether to apply gentle audio augmentation (for training only).
        """
        self.root_dir = root_dir
        self.representation = representation.lower()
        self.classes = sorted(os.listdir(root_dir))
        self.file_paths = []
        self.labels = []
        self.transform = transform
        self.augment = augment  # [v12] Gentle augmentation flag
        
        # Validate representation type
        valid_representations = ['spectrogram', 'cqt_chromagram']
        if self.representation not in valid_representations:
            raise ValueError(f"representation must be one of {valid_representations}, got '{representation}'")

        # Map class names to indices
        self.class_to_idx = {cls_name: i for i, cls_name in enumerate(self.classes)}
        
        for cls_name in self.classes:
            cls_folder = os.path.join(root_dir, cls_name)
            if os.path.isdir(cls_folder):
                for file_name in os.listdir(cls_folder):
                    if file_name.endswith('.wav'):
                        self.file_paths.append(os.path.join(cls_folder, file_name))
                        self.labels.append(self.class_to_idx[cls_name])

    def __len__(self):
        return len(self.file_paths)
    
    def _compute_spectrogram(self, y):
        """Compute STFT-based power spectrogram."""
        # Compute STFT
        stft_matrix = librosa.stft(y, n_fft=n_fft, hop_length=hop_length)
        
        # Calculate Spectrogram: |S(t,f)|^2 
        spectrogram = np.abs(stft_matrix) ** 2
        
        # Convert to dB scale (Logarithmic)
        log_spectrogram = librosa.power_to_db(spectrogram, ref=np.max)
        
        return log_spectrogram
    
    def _compute_cqt_chromagram(self, y, sr):
        """
        Compute Constant-Q chromagram.
        
        The CQT chromagram maps the audio to 12 pitch classes (C, C#, D, ..., B)
        with logarithmic frequency resolution - ideal for chord recognition.
        """
        # Compute CQT-based chromagram
        # n_chroma=12 gives us the 12 pitch classes
        # Using CQT instead of STFT for better frequency resolution at low frequencies
        chromagram = librosa.feature.chroma_cqt(
            y=y, 
            sr=sr, 
            hop_length=hop_length,
            n_chroma=12,  # 12 pitch classes
            n_octaves=7,  # Cover 7 octaves (good range for guitar)
        )
        
        # Chromagram is already in [0, 1] range typically, but let's normalize
        # Convert to dB-like scale for better visualization and learning
        # Add small epsilon to avoid log(0)
        chromagram_db = librosa.amplitude_to_db(chromagram + 1e-10, ref=np.max)
        
        return chromagram_db
    
    def _augment_audio(self, y, sr):
        """
        [v12] GENTLE audio augmentations - pitch-safe only.
        
        Only 3 augmentations with LOW probability and NARROW ranges:
            - Time stretching: 0.95-1.05x (20% prob) - subtle speed variation
            - Volume change: 0.85-1.15 (20% prob) - simulates dynamics  
            - Time shift: 5% (15% prob) - minor temporal shift
        """
        target_len = int(sr * DURATION)
        
        # 1. Gentle time stretching (20% probability, narrow range)
        if np.random.random() < 0.2:
            rate = np.random.uniform(0.95, 1.05)  # Only ±5% stretch
            y = librosa.effects.time_stretch(y, rate=rate)
            # Ensure consistent length after stretch
            if len(y) > target_len:
                y = y[:target_len]
            elif len(y) < target_len:
                y = np.pad(y, (0, target_len - len(y)), 'constant')
        
        # 2. Gentle volume change (20% probability, narrow range)
        if np.random.random() < 0.2:
            gain = np.random.uniform(0.85, 1.15)  # Only ±15% volume
            y = y * gain
            y = np.clip(y, -1.0, 1.0)  # Prevent clipping
        
        # 3. Small time shift (15% probability, only ±5%)
        if np.random.random() < 0.15:
            shift = int(np.random.uniform(-0.05, 0.05) * len(y))  # Only ±5% shift
            y = np.roll(y, shift)
        
        return y

    def __getitem__(self, idx):
        audio_path = self.file_paths[idx]
        label = self.labels[idx]

        # Load audio (ensure consistent duration)
        y, sr = librosa.load(audio_path, sr=SAMPLE_RATE, duration=DURATION)
        
        # Padding if audio is too short
        if len(y) < SAMPLE_RATE * DURATION:
            padding = SAMPLE_RATE * DURATION - len(y)
            y = np.pad(y, (0, padding), 'constant')

        # [v12] Apply gentle augmentation (only during training)
        if self.augment:
            y = self._augment_audio(y, sr)

        # Compute the selected representation
        if self.representation == 'spectrogram':
            feature_matrix = self._compute_spectrogram(y)
        elif self.representation == 'cqt_chromagram':
            feature_matrix = self._compute_cqt_chromagram(y, sr)

        # Normalize to 0-255 for image representation
        norm_feature = (feature_matrix - feature_matrix.min()) / (feature_matrix.max() - feature_matrix.min() + 1e-10)
        norm_feature = (norm_feature * 255).astype(np.uint8)

        # Convert to PIL Image to use Torchvision transforms
        img = Image.fromarray(norm_feature)
        
        # Convert grayscale (1 channel) to RGB (3 channels) as AlexNet expects 3 inputs
        img = img.convert("RGB")

        # Resize to 227x227 
        resize_transform = transforms.Compose([
            transforms.Resize(INPUT_SIZE),
            transforms.ToTensor(),
            # Normalize with ImageNet stats (standard for AlexNet)
            transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
        ])
        
        img_tensor = resize_transform(img)

        return img_tensor, label

# %%
class AlexNetChordClassifier(nn.Module):
    """
    AlexNet architecture with Batch Normalization (v12).
    
    BatchNorm2d added after each Conv2d layer for:
        - Improved training stability
        - Faster convergence
        - Better generalization
    """
    def __init__(self, num_classes=NUM_CLASSES):
        super(AlexNetChordClassifier, self).__init__()
        self.features = nn.Sequential(
            # Layer 1: Conv 11x11, Stride 4, 96 filters + BatchNorm
            nn.Conv2d(3, 96, kernel_size=11, stride=4, padding=0),
            nn.BatchNorm2d(96),  # [v12] Added BatchNorm
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),

            # Layer 2: Conv 5x5, Stride 1, 256 filters + BatchNorm
            nn.Conv2d(96, 256, kernel_size=5, padding=2),
            nn.BatchNorm2d(256),  # [v12] Added BatchNorm
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),

            # Layer 3: Conv 3x3, Stride 1, 384 filters + BatchNorm
            nn.Conv2d(256, 384, kernel_size=3, padding=1),
            nn.BatchNorm2d(384),  # [v12] Added BatchNorm
            nn.ReLU(inplace=True),

            # Layer 4: Conv 3x3, Stride 1, 384 filters + BatchNorm
            nn.Conv2d(384, 384, kernel_size=3, padding=1),
            nn.BatchNorm2d(384),  # [v12] Added BatchNorm
            nn.ReLU(inplace=True),

            # Layer 5: Conv 3x3, Stride 1, 256 filters + BatchNorm
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),  # [v12] Added BatchNorm
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        
        self.avgpool = nn.AdaptiveAvgPool2d((6, 6))
        
        self.classifier = nn.Sequential(
            nn.Dropout(),
            # Flattened Input Size: 6x6x256 -> 4096
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            # Fully Connected Layer: 4096
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            # Output Layer: Number of Classes
            nn.Linear(4096, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# %%
def plot_training_curves(train_losses, val_losses, val_accuracies):
    """Plot training and validation metrics over epochs."""
    epochs = range(1, len(train_losses) + 1)
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
    
    # Plot losses
    ax1.plot(epochs, train_losses, 'b-', label='Training Loss', linewidth=2)
    ax1.plot(epochs, val_losses, 'r-', label='Validation Loss', linewidth=2)
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss')
    ax1.set_title('Training and Validation Loss')
    ax1.legend()
    ax1.grid(True, alpha=0.3)
    
    # Mark best epoch
    best_epoch = val_losses.index(min(val_losses)) + 1
    ax1.axvline(x=best_epoch, color='g', linestyle='--', alpha=0.7, label=f'Best epoch ({best_epoch})')
    ax1.legend()
    
    # Plot validation accuracy
    ax2.plot(epochs, val_accuracies, 'g-', label='Validation Accuracy', linewidth=2)
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Accuracy')
    ax2.set_title('Validation Accuracy')
    ax2.legend()
    ax2.grid(True, alpha=0.3)
    ax2.axvline(x=best_epoch, color='r', linestyle='--', alpha=0.7, label=f'Best epoch ({best_epoch})')
    ax2.legend()
    
    plt.tight_layout()
    plt.savefig('training_curves_v12.png', dpi=150)
    print("Training curves saved to: training_curves_v12.png")
    plt.show()
    plt.close()

# %%
def evaluate_model(model, test_loader, test_dataset, device, save_confusion_matrix=True):
    """
    Evaluate the AlexNet model on the test dataset.
    Reports accuracy, F1 score, classification report, and confusion matrix.
    """
    print("\n" + "=" * 60)
    print("AlexNet Chord Classification - Model Evaluation (v12 - BatchNorm + Gentle Aug)")
    print("=" * 60)
    
    model.eval()
    
    y_true = []
    y_pred = []
    
    # Get class names from dataset
    idx_to_class = {v: k for k, v in test_dataset.class_to_idx.items()}
    class_names = [idx_to_class[i] for i in range(len(idx_to_class))]
    
    # Show representation type used
    representation = getattr(test_dataset, 'representation', 'unknown')
    print(f"\nRepresentation: {representation}")
    print(f"Classes: {class_names}")
    print(f"Number of test samples: {len(test_dataset)}")
    
    # Count samples per class
    print("\nSamples per class:")
    class_counts = {}
    for label in test_dataset.labels:
        cls_name = idx_to_class[label]
        class_counts[cls_name] = class_counts.get(cls_name, 0) + 1
    for chord in sorted(class_counts.keys()):
        print(f"  {chord}: {class_counts[chord]}")
    
    # Run predictions
    print("\nRunning predictions...")
    with torch.no_grad():
        for inputs, labels in tqdm(test_loader, desc="Evaluating"):
            inputs = inputs.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())
    
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    
    # Calculate metrics
    print("\n" + "=" * 60)
    print("EVALUATION RESULTS")
    print("=" * 60)
    
    # Accuracy
    accuracy = accuracy_score(y_true, y_pred)
    print(f"\nAccuracy: {accuracy:.4f} ({accuracy * 100:.2f}%)")
    
    # F1 Scores
    f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
    f1_weighted = f1_score(y_true, y_pred, average='weighted', zero_division=0)
    print(f"F1 Score (Macro):    {f1_macro:.4f}")
    print(f"F1 Score (Weighted): {f1_weighted:.4f}")
    
    # Classification Report
    print("\n" + "-" * 60)
    print("CLASSIFICATION REPORT")
    print("-" * 60)
    print(classification_report(y_true, y_pred, target_names=class_names, zero_division=0))
    
    # Show misclassification details
    incorrect_indices = np.where(y_true != y_pred)[0]
    if len(incorrect_indices) > 0:
        print("\n" + "-" * 60)
        print(f"SAMPLE MISCLASSIFICATIONS ({len(incorrect_indices)} total errors)")
        print("-" * 60)
        for i, idx in enumerate(incorrect_indices[:15]):
            true_label = idx_to_class[y_true[idx]]
            pred_label = idx_to_class[y_pred[idx]]
            file_name = os.path.basename(test_dataset.file_paths[idx])
            print(f"  {true_label:5s} -> {pred_label:5s} | {file_name}")
        if len(incorrect_indices) > 15:
            print(f"  ... and {len(incorrect_indices) - 15} more errors")
    
    # Confusion Matrix
    if save_confusion_matrix:
        print("\nGenerating confusion matrix...")
        
        cm = confusion_matrix(y_true, y_pred)
        
        plt.figure(figsize=(16, 14))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                    xticklabels=class_names,
                    yticklabels=class_names)
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.title(f'AlexNet Chord Recognition v12 - BatchNorm + Gentle Aug ({representation})\nAccuracy: {accuracy:.2%} | F1 (Macro): {f1_macro:.4f}')
        plt.xticks(rotation=45, ha='right')
        plt.yticks(rotation=0)
        plt.tight_layout()
        cm_filename = f'confusion_matrix_alexnet_v12_{representation}.png'
        plt.savefig(cm_filename, dpi=150)
        print(f"Confusion matrix saved to: {cm_filename}")
        plt.show()
        plt.close()
    
    # Summary
    print("\n" + "=" * 60)
    print("SUMMARY")
    print("=" * 60)
    print(f"Total samples:     {len(y_true)}")
    print(f"Correct:           {np.sum(y_true == y_pred)}")
    print(f"Incorrect:         {np.sum(y_true != y_pred)}")
    print(f"Accuracy:          {accuracy:.2%}")
    print(f"F1 Score (Macro):  {f1_macro:.4f}")
    print("=" * 60)
    
    return {
        'accuracy': accuracy,
        'f1_macro': f1_macro,
        'f1_weighted': f1_weighted,
        'y_true': y_true,
        'y_pred': y_pred,
        'class_names': class_names
    }

# %%
def train_model(representation='spectrogram', early_stopping_patience=5):
    """
    Train the AlexNet chord classifier with validation tracking.
    
    v12 Changes:
        - BatchNorm2d layers after each Conv2d
        - GENTLE audio augmentation (from v10)
        - NO weighted loss (regular CrossEntropyLoss)
    
    Args:
        representation (str): Audio representation type.
            - 'spectrogram': STFT-based power spectrogram
            - 'cqt_chromagram': Constant-Q chromagram (12 pitch classes)
        early_stopping_patience (int): Number of epochs to wait for improvement before stopping.
    """
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")
    print(f"Audio representation: {representation}")
    print(f"\n[v12] BatchNorm + Gentle Audio Augmentation")

    # Paths
    train_dir = '/kaggle/input/guitarset-chord-recognition/chords/train'
    val_dir = '/kaggle/input/guitarset-chord-recognition/chords/val'
    test_dir = '/kaggle/input/guitarset-chord-recognition/chords/test'

    # Initialize Datasets - augment=True only for training
    train_dataset = GuitarChordDataset(train_dir, representation=representation, augment=True)
    val_dataset = GuitarChordDataset(val_dir, representation=representation, augment=False)
    test_dataset = GuitarChordDataset(test_dir, representation=representation, augment=False)
    
    print(f"\n[v12] Model changes:")
    print(f"  - BatchNorm2d after each Conv2d layer")
    print(f"\n[v12] Augmentations enabled for training:")
    print(f"  - Time stretch: ±5% @ 20% probability")
    print(f"  - Volume change: ±15% @ 20% probability")
    print(f"  - Time shift: ±5% @ 15% probability")

    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)
    
    print(f"\nTraining samples: {len(train_dataset)}")
    print(f"Validation samples: {len(val_dataset)}")
    print(f"Test samples: {len(test_dataset)}")

    # Initialize Model
    model = AlexNetChordClassifier(num_classes=NUM_CLASSES).to(device)

    # [v12] Regular CrossEntropyLoss (no class weights)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
    
    print(f"\nLoss function: CrossEntropyLoss (no weights)") 

    # Tracking metrics
    train_losses = []
    val_losses = []
    val_accuracies = []
    
    # Early stopping variables
    best_val_loss = float('inf')
    best_model_state = None
    epochs_without_improvement = 0

    # Training Loop
    for epoch in range(EPOCHS):
        # ==================== TRAINING ====================
        model.train()
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
        
        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)
        
        # ==================== VALIDATION ====================
        model.eval()
        val_running_loss = 0.0
        correct = 0
        total = 0
        
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_running_loss += loss.item()
                
                # Calculate accuracy
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        
        val_loss = val_running_loss / len(val_loader)
        val_accuracy = correct / total
        val_losses.append(val_loss)
        val_accuracies.append(val_accuracy)
        
        # Print epoch results
        print(f"Epoch {epoch+1}/{EPOCHS} | "
              f"Train Loss: {train_loss:.4f} | "
              f"Val Loss: {val_loss:.4f} | "
              f"Val Acc: {val_accuracy:.4f}")
        
        # ==================== EARLY STOPPING ====================
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_state = copy.deepcopy(model.state_dict())
            epochs_without_improvement = 0
            print(f"  ✓ New best validation loss!")
        else:
            epochs_without_improvement += 1
            if early_stopping_patience and epochs_without_improvement >= early_stopping_patience:
                print(f"\nEarly stopping triggered after {epoch+1} epochs (no improvement for {early_stopping_patience} epochs)")
                break
    
    # Load best model weights
    if best_model_state is not None:
        model.load_state_dict(best_model_state)
        print(f"\nLoaded best model (val_loss: {best_val_loss:.4f})")

    print("Training Complete")
    
    # Plot training curves
    plot_training_curves(train_losses, val_losses, val_accuracies)
    
    # Return model and test components for evaluation
    return model, test_loader, test_dataset, device

# %%
model, test_loader, test_dataset, device = train_model(
    representation=REPRESENTATION,
    early_stopping_patience=EARLY_STOPPING_PATIENCE
)
# Out:
# Using device: cuda
# Audio representation: cqt_chromagram
#
# [v12] BatchNorm + Gentle Audio Augmentation
#
# [v12] Model changes:
#   - BatchNorm2d after each Conv2d layer
#
# [v12] Augmentations enabled for training:
#   - Time stretch: ±5% @ 20% probability
#   - Volume change: ±15% @ 20% probability
#   - Time shift: ±5% @ 15% probability
#
# Training samples: 1852
# Validation samples: 222
# Test samples: 254
#
# Loss function: CrossEntropyLoss (no weights)
# /usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
# Epoch 1/100 | Train Loss: 4.2968 | Val Loss: 2.9985 | Val Acc: 0.1036
#   ✓ New best validation loss!
# Epoch 2/100 | Train Loss: 2.9331 | Val Loss: 2.7141 | Val Acc: 0.2342
#   ✓ New best validation loss!
# Epoch 3/100 | Train Loss: 2.7632 | Val Loss: 2.5812 | Val Acc: 0.2387
#   ✓ New best validation loss!
# Epoch 4/100 | Train Loss: 2.5591 | Val Loss: 2.2943 | Val Acc: 0.3468
#   ✓ New best validation loss!
# Epoch 5/100 | Train Loss: 2.5257 | Val Loss: 2.4073 | Val Acc: 0.2793
# Epoch 6/100 | Train Loss: 2.4292 | Val Loss: 2.3147 | Val Acc: 0.3243
# Epoch 7/100 | Train Loss: 2.3891 | Val Loss: 1.9339 | Val Acc: 0.4009
#   ✓ New best validation loss!
# Epoch 8/100 | Train Loss: 2.3024 | Val Loss: 1.9385 | Val Acc: 0.4324
# Epoch 9/100 | Train Loss: 2.3067 | Val Loss: 1.9841 | Val Acc: 0.3829
# Epoch 10/100 | Train Loss: 2.2273 | Val Loss: 1.9543 | Val Acc: 0.3739
# Epoch 11/100 | Train Loss: 2.1840 | Val Loss: 1.8607 | Val Acc: 0.4505
#   ✓ New best validation loss!
# Epoch 12/100 | Train Loss: 2.1522 | Val Loss: 1.7354 | Val Acc: 0.4505
#   ✓ New best validation loss!
# Epoch 13/100 | Train Loss: 2.1627 | Val Loss: 1.9460 | Val Acc: 0.4640
# Epoch 14/100 | Train Loss: 2.0978 | Val Loss: 1.6820 | Val Acc: 0.4730
#   ✓ New best validation loss!
# Epoch 15/100 | Train Loss: 2.1188 | Val Loss: 1.7126 | Val Acc: 0.5180
# Epoch 16/100 | Train Loss: 1.9873 | Val Loss: 1.8073 | Val Acc: 0.4369
# Epoch 17/100 | Train Loss: 2.0114 | Val Loss: 1.5625 | Val Acc: 0.5586
#   ✓ New best validation loss!
# Epoch 18/100 | Train Loss: 2.0082 | Val Loss: 1.8072 | Val Acc: 0.4955
# Epoch 19/100 | Train Loss: 1.9863 | Val Loss: 1.6529 | Val Acc: 0.4595
# Epoch 20/100 | Train Loss: 1.9665 | Val Loss: 1.6199 | Val Acc: 0.5000
# Epoch 21/100 | Train Loss: 1.9553 | Val Loss: 1.5924 | Val Acc: 0.5225
# Epoch 22/100 | Train Loss: 1.8946 | Val Loss: 1.5017 | Val Acc: 0.5315
#   ✓ New best validation loss!
# Epoch 23/100 | Train Loss: 1.9088 | Val Loss: 1.5202 | Val Acc: 0.6036
# Epoch 24/100 | Train Loss: 1.8375 | Val Loss: 1.6217 | Val Acc: 0.5270
# Epoch 25/100 | Train Loss: 1.8337 | Val Loss: 1.5176 | Val Acc: 0.5586
# Epoch 26/100 | Train Loss: 1.8534 | Val Loss: 1.5114 | Val Acc: 0.6036
# Epoch 27/100 | Train Loss: 1.7936 | Val Loss: 1.4379 | Val Acc: 0.5360
#   ✓ New best validation loss!
# Epoch 28/100 | Train Loss: 1.7980 | Val Loss: 1.5214 | Val Acc: 0.5225
# Epoch 29/100 | Train Loss: 1.7857 | Val Loss: 1.5213 | Val Acc: 0.5315
# Epoch 30/100 | Train Loss: 1.8024 | Val Loss: 1.4190 | Val Acc: 0.5946
#   ✓ New best validation loss!
# Epoch 31/100 | Train Loss: 1.7565 | Val Loss: 1.4963 | Val Acc: 0.5405
# Epoch 32/100 | Train Loss: 1.7656 | Val Loss: 1.5634 | Val Acc: 0.5360
# Epoch 33/100 | Train Loss: 1.7374 | Val Loss: 1.5443 | Val Acc: 0.5766
# Epoch 34/100 | Train Loss: 1.7051 | Val Loss: 1.3913 | Val Acc: 0.6126
#   ✓ New best validation loss!
# Epoch 35/100 | Train Loss: 1.7234 | Val Loss: 1.3538 | Val Acc: 0.6036
#   ✓ New best validation loss!
# Epoch 36/100 | Train Loss: 1.7200 | Val Loss: 1.4846 | Val Acc: 0.5991
# Epoch 37/100 | Train Loss: 1.6728 | Val Loss: 1.4791 | Val Acc: 0.5766
# Epoch 38/100 | Train Loss: 1.6652 | Val Loss: 1.4837 | Val Acc: 0.5315
# Epoch 39/100 | Train Loss: 1.6032 | Val Loss: 1.3248 | Val Acc: 0.6036
#   ✓ New best validation loss!
# Epoch 40/100 | Train Loss: 1.6494 | Val Loss: 1.3684 | Val Acc: 0.5676
# Epoch 41/100 | Train Loss: 1.6808 | Val Loss: 1.3876 | Val Acc: 0.5856
# Epoch 42/100 | Train Loss: 1.6685 | Val Loss: 1.4528 | Val Acc: 0.5766
# Epoch 43/100 | Train Loss: 1.6017 | Val Loss: 1.3716 | Val Acc: 0.6171
# Epoch 44/100 | Train Loss: 1.6174 | Val Loss: 1.4465 | Val Acc: 0.5811
# Epoch 45/100 | Train Loss: 1.5937 | Val Loss: 1.2785 | Val Acc: 0.6532
#   ✓ New best validation loss!
# Epoch 46/100 | Train Loss: 1.5605 | Val Loss: 1.3069 | Val Acc: 0.6081
# Epoch 47/100 | Train Loss: 1.5516 | Val Loss: 1.3121 | Val Acc: 0.6396
# Epoch 48/100 | Train Loss: 1.5603 | Val Loss: 1.3407 | Val Acc: 0.6532
# Epoch 49/100 | Train Loss: 1.5572 | Val Loss: 1.3892 | Val Acc: 0.6081
# Epoch 50/100 | Train Loss: 1.5327 | Val Loss: 1.3789 | Val Acc: 0.6396
# Epoch 51/100 | Train Loss: 1.5463 | Val Loss: 1.4663 | Val Acc: 0.6036
# Epoch 52/100 | Train Loss: 1.5493 | Val Loss: 1.3277 | Val Acc: 0.6396
# Epoch 53/100 | Train Loss: 1.4928 | Val Loss: 1.3135 | Val Acc: 0.5946
# Epoch 54/100 | Train Loss: 1.4881 | Val Loss: 1.3768 | Val Acc: 0.5991
# Epoch 55/100 | Train Loss: 1.4625 | Val Loss: 1.3265 | Val Acc: 0.6712
# Epoch 56/100 | Train Loss: 1.4414 | Val Loss: 1.2783 | Val Acc: 0.6126
#   ✓ New best validation loss!
# Epoch 57/100 | Train Loss: 1.4214 | Val Loss: 1.2689 | Val Acc: 0.6441
#   ✓ New best validation loss!
# Epoch 58/100 | Train Loss: 1.3885 | Val Loss: 1.2950 | Val Acc: 0.6396
# Epoch 59/100 | Train Loss: 1.4083 | Val Loss: 1.2799 | Val Acc: 0.6847
# Epoch 60/100 | Train Loss: 1.4151 | Val Loss: 1.2885 | Val Acc: 0.6351
# Epoch 61/100 | Train Loss: 1.3584 | Val Loss: 1.2743 | Val Acc: 0.6261
# Epoch 62/100 | Train Loss: 1.3366 | Val Loss: 1.3440 | Val Acc: 0.5811
# Epoch 63/100 | Train Loss: 1.3851 | Val Loss: 1.3262 | Val Acc: 0.6216
# Epoch 64/100 | Train Loss: 1.3382 | Val Loss: 1.2867 | Val Acc: 0.6577
# Epoch 65/100 | Train Loss: 1.3564 | Val Loss: 1.2986 | Val Acc: 0.6396
# Epoch 66/100 | Train Loss: 1.3242 | Val Loss: 1.2735 | Val Acc: 0.6532
# Epoch 67/100 | Train Loss: 1.3450 | Val Loss: 1.1762 | Val Acc: 0.6937
#   ✓ New best validation loss!
# Epoch 68/100 | Train Loss: 1.2938 | Val Loss: 1.3352 | Val Acc: 0.6396
# Epoch 69/100 | Train Loss: 1.2491 | Val Loss: 1.3261 | Val Acc: 0.6532
# Epoch 70/100 | Train Loss: 1.2863 | Val Loss: 1.3078 | Val Acc: 0.6171
# Epoch 71/100 | Train Loss: 1.2817 | Val Loss: 1.3038 | Val Acc: 0.6486
# Epoch 72/100 | Train Loss: 1.2624 | Val Loss: 1.3244 | Val Acc: 0.6667
# Epoch 73/100 | Train Loss: 1.2545 | Val Loss: 1.2731 | Val Acc: 0.6802
# Epoch 74/100 | Train Loss: 1.2415 | Val Loss: 1.2044 | Val Acc: 0.6532
# Epoch 75/100 | Train Loss: 1.1741 | Val Loss: 1.3774 | Val Acc: 0.5946
# Epoch 76/100 | Train Loss: 1.1186 | Val Loss: 1.2168 | Val Acc: 0.6757
# Epoch 77/100 | Train Loss: 1.1009 | Val Loss: 1.1212 | Val Acc: 0.6937
#   ✓ New best validation loss!
# Epoch 78/100 | Train Loss: 1.1385 | Val Loss: 1.2972 | Val Acc: 0.6351
# Epoch 79/100 | Train Loss: 1.0705 | Val Loss: 1.0829 | Val Acc: 0.7027
#   ✓ New best validation loss!
# Epoch 80/100 | Train Loss: 1.0474 | Val Loss: 1.1086 | Val Acc: 0.7027
# Epoch 81/100 | Train Loss: 1.0412 | Val Loss: 1.0941 | Val Acc: 0.7162
# Epoch 82/100 | Train Loss: 0.9925 | Val Loss: 1.0224 | Val Acc: 0.7162
#   ✓ New best validation loss!
# Epoch 83/100 | Train Loss: 0.9547 | Val Loss: 1.1422 | Val Acc: 0.6847
# Epoch 84/100 | Train Loss: 0.9662 | Val Loss: 1.0327 | Val Acc: 0.7117
# Epoch 85/100 | Train Loss: 0.9618 | Val Loss: 1.1605 | Val Acc: 0.6892
# Epoch 86/100 | Train Loss: 0.9054 | Val Loss: 1.0549 | Val Acc: 0.7117
# Epoch 87/100 | Train Loss: 0.9216 | Val Loss: 1.0680 | Val Acc: 0.7162
# Epoch 88/100 | Train Loss: 0.8662 | Val Loss: 1.0717 | Val Acc: 0.7072
# Epoch 89/100 | Train Loss: 0.8720 | Val Loss: 0.9973 | Val Acc: 0.7207
#   ✓ New best validation loss!
# Epoch 90/100 | Train Loss: 0.8408 | Val Loss: 1.0623 | Val Acc: 0.7207
# Epoch 91/100 | Train Loss: 0.7966 | Val Loss: 1.0260 | Val Acc: 0.7162
# Epoch 92/100 | Train Loss: 0.8235 | Val Loss: 1.0011 | Val Acc: 0.7297
# Epoch 93/100 | Train Loss: 0.7621 | Val Loss: 1.0320 | Val Acc: 0.7297
# Epoch 94/100 | Train Loss: 0.7573 | Val Loss: 0.9462 | Val Acc: 0.7432
#   ✓ New best validation loss!
# Epoch 95/100 | Train Loss: 0.7368 | Val Loss: 0.9347 | Val Acc: 0.7342
#   ✓ New best validation loss!
# Epoch 96/100 | Train Loss: 0.7746 | Val Loss: 0.9350 | Val Acc: 0.7297
# Epoch 97/100 | Train Loss: 0.7066 | Val Loss: 1.0156 | Val Acc: 0.7252
# Epoch 98/100 | Train Loss: 0.7024 | Val Loss: 1.0053 | Val Acc: 0.7072
# Epoch 99/100 | Train Loss: 0.6839 | Val Loss: 0.9480 | Val Acc: 0.7297
# Epoch 100/100 | Train Loss: 0.7293 | Val Loss: 0.9766 | Val Acc: 0.7387
#
# Loaded best model (val_loss: 0.9347)
# Training Complete
# Training curves saved to: training_curves_v12.png

# %%
results = evaluate_model(model, test_loader, test_dataset, device)
# Out:
# ============================================================
# AlexNet Chord Classification - Model Evaluation (v12 - BatchNorm + Gentle Aug)
# ============================================================
#
# Representation: cqt_chromagram
# Classes: ['A', 'A#', 'A#m', 'Am', 'B', 'Bm', 'C', 'C#', 'C#m', 'Cm', 'D', 'D#', 'D#m', 'Dm', 'E', 'Em', 'F', 'F#', 'F#m', 'Fm', 'G', 'G#', 'G#m', 'Gm']
# Number of test samples: 254
#
# Samples per class:
#   A: 11
#   A#: 11
#   A#m: 12
#   Am: 6
#   B: 11
#   Bm: 8
#   C: 12
#   C#: 12
#   C#m: 8
#   Cm: 5
#   D: 11
#   D#: 12
#   D#m: 8
#   Dm: 9
#   E: 12
#   Em: 9
#   F: 15
#   F#: 11
#   F#m: 6
#   Fm: 15
#   G: 14
#   G#: 12
#   G#m: 12
#   Gm: 12
#
# Running predictions...
# Evaluating: 100%|██████████| 8/8 [00:28<00:00,  3.60s/it]
# ============================================================
# EVALUATION RESULTS
# ============================================================
#
# Accuracy: 0.7362 (73.62%)
# F1 Score (Macro):    0.7048
# F1 Score (Weighted): 0.7299
#
# ------------------------------------------------------------
# CLASSIFICATION REPORT
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            A       0.56      0.91      0.69        11
#           A#       1.00      0.73      0.84        11
#          A#m       0.77      0.83      0.80        12
#           Am       0.50      0.17      0.25         6
#            B       0.71      0.45      0.56        11
#           Bm       0.64      0.88      0.74         8
#            C       0.91      0.83      0.87        12
#           C#       0.83      0.83      0.83        12
#          C#m       0.60      0.75      0.67         8
#           Cm       0.67      0.40      0.50         5
#            D       0.73      0.73      0.73        11
#           D#       1.00      0.83      0.91        12
#          D#m       0.44      0.88      0.58         8
#           Dm       1.00      0.44      0.62         9
#            E       0.71      0.42      0.53        12
#           Em       0.78      0.78      0.78         9
#            F       0.92      0.73      0.81        15
#           F#       1.00      0.55      0.71        11
#          F#m       0.50      0.83      0.62         6
#           Fm       0.78      0.93      0.85        15
#            G       0.82      1.00      0.90        14
#           G#       0.64      0.58      0.61        12
#          G#m       0.80      0.67      0.73        12
#           Gm       0.67      1.00      0.80        12
#
#     accuracy                           0.74       254
#    macro avg       0.75      0.71      0.70       254
# weighted avg       0.77      0.74      0.73       254
#
#
# ------------------------------------------------------------
# SAMPLE MISCLASSIFICATIONS (67 total errors)
# ------------------------------------------------------------
#   A     -> F#m   | 05_Funk3-98-A_comp_0.000_2.449.wav
#   A#    -> A#m   | 02_Funk2-119-G_comp_20.168_22.185.wav
#   A#    -> Gm    | 00_Jazz3-137-Eb_comp_26.277_28.023.wav
#   A#    -> A#m   | 02_Jazz3-137-Eb_comp_12.263_14.015.wav
#   A#m   -> Gm    | 05_Funk3-112-Cd_comp_21.429_23.571_w0.wav
#   A#m   -> D#m   | 03_Jazz2-110-Bb_comp_13.091_17.455_w2.wav
#   Am    -> Fm    | 04_Jazz3-150-C_comp_3.200_4.800.wav
#   Am    -> A     | 02_Rock3-148-C_comp_3.243_4.865.wav
#   Am    -> A     | 01_Rock3-148-C_comp_3.243_4.865.wav
#   Am    -> A     | 03_SS3-98-C_comp_4.898_7.347_w0.wav
#   Am    -> A     | 00_SS3-98-C_comp_4.898_7.347_w1.wav
#   B     -> Bm    | 02_SS2-107-Ab_comp_4.486_6.729.wav
#   B     -> D#m   | 03_Jazz1-200-B_comp_7.200_9.600.wav
#   B     -> D#m   | 00_Funk2-108-Eb_comp_6.667_8.889.wav
#   B     -> D#m   | 04_Funk2-108-Eb_comp_24.444_26.667.wav
#   ... and 52 more errors
#
# Generating confusion matrix...
# Confusion matrix saved to: confusion_matrix_alexnet_v12_cqt_chromagram.png
# ============================================================
# SUMMARY
# ============================================================
# Total samples:     254
# Correct:           187
# Incorrect:         67
# Accuracy:          73.62%
# F1 Score (Macro):  0.7048
# ============================================================

# %%
# SAVE MODEL FOR DEPLOYMENT (PTH + ONNX + Config)
# ============================================================

model.eval()
idx_to_class = {v: k for k, v in test_dataset.class_to_idx.items()}

# 1. SAVE PyTorch CHECKPOINT
checkpoint = {
    'model_state_dict': model.state_dict(),
    'class_to_idx': test_dataset.class_to_idx,
    'idx_to_class': idx_to_class,
    'config': {
        'sample_rate': SAMPLE_RATE,
        'duration': DURATION,
        'n_fft': n_fft,
        'hop_length': hop_length,
        'input_size': list(INPUT_SIZE),
        'representation': REPRESENTATION,
        'num_classes': NUM_CLASSES,
        'normalize_mean': [0.5, 0.5, 0.5],
        'normalize_std': [0.5, 0.5, 0.5],
    },
    'training_info': {
        'accuracy': results['accuracy'],
        'f1_macro': results['f1_macro'],
        'version': 'v12',
        'changes': 'BatchNorm2d after each Conv2d + Gentle audio augmentation'
    }
}

pth_path = 'alexnet_chord_classifier_v12.pth'
torch.save(checkpoint, pth_path)
print(f"✓ PyTorch checkpoint saved to: {pth_path}")

# 2. EXPORT TO ONNX
dummy_input = torch.randn(1, 3, 227, 227).to(device)
onnx_path = 'alexnet_chord_classifier_v12.onnx'
torch.onnx.export(
    model, dummy_input, onnx_path,
    export_params=True, opset_version=11,
    do_constant_folding=True,
    input_names=['input'], output_names=['output'],
    dynamic_axes={'input': {0: 'batch_size'}, 'output': {0: 'batch_size'}}
)
print(f"✓ ONNX model saved to: {onnx_path}")

# 3. SAVE CONFIG AS JSON
config_json = {
    'class_to_idx': test_dataset.class_to_idx,
    'idx_to_class': {str(k): v for k, v in idx_to_class.items()},
    'sample_rate': SAMPLE_RATE,
    'duration': DURATION,
    'n_fft': n_fft,
    'hop_length': hop_length,
    'input_size': list(INPUT_SIZE),
    'representation': REPRESENTATION,
    'num_classes': NUM_CLASSES,
    'normalize_mean': [0.5, 0.5, 0.5],
    'normalize_std': [0.5, 0.5, 0.5],
}

config_path = 'chord_model_config_v12.json'
with open(config_path, 'w') as f:
    json.dump(config_json, f, indent=2)
print(f"✓ Config saved to: {config_path}")

print("\n" + "=" * 60)
print("MODEL EXPORT COMPLETE (v12)")
print("=" * 60)
# Out:
# ✓ PyTorch checkpoint saved to: alexnet_chord_classifier_v12.pth
# ✓ ONNX model saved to: alexnet_chord_classifier_v12.onnx
# ✓ Config saved to: chord_model_config_v12.json
#
# ============================================================
# MODEL EXPORT COMPLETE (v12)
# ============================================================

# %%
# Compare with previous versions
print("\n" + "=" * 60)
print("COMPARISON WITH PREVIOUS VERSIONS")
print("=" * 60)
print(f"\nv5  (baseline):              79.92% accuracy, F1=0.7823")
print(f"v6  (+class weights):        77.17% accuracy, F1=0.7438  ↓")
print(f"v7  (+weights+HEAVY aug):    74.02% accuracy, F1=0.7278  ↓")
print(f"v10 (GENTLE aug only):       80.71% accuracy, F1=0.7887  ✓ Previous best")
print(f"v12 (BatchNorm + gentle aug): {results['accuracy']*100:.2f}% accuracy, F1={results['f1_macro']:.4f}")
print("\n" + "=" * 60)
print("v12 changes:")
print("  Architecture:")
print("    - BatchNorm2d after each Conv2d layer")
print("  Augmentations (pitch-safe):")
print("    - Time stretch: ±5% @ 20% probability")
print("    - Volume change: ±15% @ 20% probability")
print("    - Time shift: ±5% @ 15% probability")
print("  Loss: CrossEntropyLoss (no class weights)")
print("=" * 60)
# Out:
# ============================================================
# COMPARISON WITH PREVIOUS VERSIONS
# ============================================================
#
# v5  (baseline):              79.92% accuracy, F1=0.7823
# v6  (+class weights):        77.17% accuracy, F1=0.7438  ↓
# v7  (+weights+HEAVY aug):    74.02% accuracy, F1=0.7278  ↓
# v10 (GENTLE aug only):       80.71% accuracy, F1=0.7887  ✓ Previous best
# v12 (BatchNorm + gentle aug): 73.62% accuracy, F1=0.7048
#
# ============================================================
# v12 changes:
#   Architecture:
#     - BatchNorm2d after each Conv2d layer
#   Augmentations (pitch-safe):
#     - Time stretch: ±5% @ 20% probability
#     - Volume change: ±15% @ 20% probability
#     - Time shift: ±5% @ 15% probability
#   Loss: CrossEntropyLoss (no class weights)
# ============================================================
